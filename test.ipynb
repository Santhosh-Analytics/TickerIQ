# %%
from pathlib import Path
from TicketIQ.config import Settings
from TicketIQ.config.main import get_settings

s = get_settings()

# %%
app_lo = logger.get_logger(__name__)
from TicketIQ.logger import get_logger
logger = get_logger(__name__)

# %%
logger.info("Loading data from kagglehub")
import kagglehub
from kagglehub import KaggleDatasetAdapter
# Set the path to the file you'd like to load
file_path = Path(s.paths.raw_data_dir) / "customer_support.csv"
print(f"File Path : {file_path}")

df = kagglehub.dataset_load(
    KaggleDatasetAdapter.PANDAS,
    "thoughtvector/customer-support-on-twitter",
    "twcs/twcs.csv",
    # str(file_path),
)
df1 = df[df["inbound"]== True].head()
# Out:
# [05/15/26 05:00:48] INFO     Loading data from kagglehub                                            ]8;id=12714468;file:///tmp/ipykernel_11774/2392233311.py\2392233311.py]8;;\:]8;id=12714469;file:///tmp/ipykernel_11774/2392233311.py#1\1]8;;\
# File Path : /home/san/Projects/TicketIQ/data/raw/customer_support.csv

# %%
df1.drop(columns=["tweet_id","tweet_id","in_response_to_tweet_id","response_tweet_id"])
# Out:
#   author_id  inbound                      created_at  \
# 1    115712     True  Tue Oct 31 22:11:45 +0000 2017
# 2    115712     True  Tue Oct 31 22:08:27 +0000 2017
# 4    115712     True  Tue Oct 31 21:49:35 +0000 2017
# 6    115712     True  Tue Oct 31 21:45:10 +0000 2017
# 8    115713     True  Tue Oct 31 22:04:47 +0000 2017
#
#                                                 text
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare I have sent several private messag...
# 4                                 @sprintcare I did.
# 6          @sprintcare is the worst customer service
# 8  @sprintcare You gonna magically change your co...

# %%
logger = get_logger(None)

logger.info("just test")
# Out:
# [05/15/26 05:09:38] INFO     just test                                                              ]8;id=12714484;file:///tmp/ipykernel_11774/1624225836.py\1624225836.py]8;;\:]8;id=12714485;file:///tmp/ipykernel_11774/1624225836.py#3\3]8;;\
